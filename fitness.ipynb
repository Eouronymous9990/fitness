# %% [markdown]
# ### Fitness Pipeline

# %%
import os
import cv2
import sys
import math
import numpy as np

from ultralytics import YOLO
from collections import deque
import plotly.graph_objects as go
